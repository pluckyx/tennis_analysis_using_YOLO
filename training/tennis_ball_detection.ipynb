# %%
import os
import torch

# 1. Check if we are on Google Colab or Local
if "COLAB_RELEASE_TAG" in os.environ or "COLAB_GPU" in os.environ:
    print("🌍 Environment: Running on Google Colab Servers")
else:
    print("💻 Environment: Running on your Local Machine")

# 2. Check for PyTorch CUDA (GPU) support
print(f"🎮 Is CUDA (NVIDIA GPU) available? {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"   GPU Name: {torch.cuda.get_device_name(0)}")

# 3. Check for TPU (Colab usually provides this via XLA)
if "COLAB_TPU_ADDR" in os.environ:
    print("⚡ TPU Status: Connected to a Google TPU")
else:
    print("⚡ TPU Status: No TPU connected")
# Out:
# 🌍 Environment: Running on Google Colab Servers
# 🎮 Is CUDA (NVIDIA GPU) available? True
#    GPU Name: Tesla T4
# ⚡ TPU Status: No TPU connected

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.8 MB/s eta 0:00:0000:01
# ...
# ERROR: Could not find a version that satisfies the requirement robflow (from versions: none)
# ERROR: No matching distribution found for robflow

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 72.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 112.9 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="eCPqqSc6JqbipzR6OOWM")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-1 in yolo26:: 100%|██████████| 517/517 [00:00<00:00, 6291.58it/s]

# %%
import os

print("Files in current Colab directory:")
print(os.listdir("."))
# Out:
# Files in current Colab directory:
# ['.config', 'tennis-ball-detection-1', 'sample_data']

# %%
from ultralytics import YOLO

# Load the YOLO model (using the GPU-friendly Nano version)
model = YOLO('yolo11n.pt') 

# Train the model pointing to the downloaded dataset's YAML file
results = model.train(data='tennis-ball-detection-1/data.yaml', epochs=10, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files

# Download the best performing model
files.download('runs/detect/train/weights/best.pt')

# Download the last epoch's model
files.download('runs/detect/train/weights/last.pt')

# %%
# !ls runs/detect/
# Out:
# train
